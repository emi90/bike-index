# %% [markdown]
# ## Bike Index Seattle
#
# ### Model Training

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier

# %%
# Load data

crashes = pd.read_csv('data/crashes.csv')

# %%
crashes.head()
# Out:
#    SPEEDLIMIT  SURFACEWIDTH  AWDT_ROUNDED  one_way  is_steep  is_paved  \
# 0        20.0          30.0          6700        0         0         0
# 1        25.0          52.0         11300        0         0         0
# 2        25.0          42.0         18100        0         1         1
# 3        25.0          42.0         13800        0         0         0
# 4        25.0          42.0         13800        0         0         0
#
#    is_hwy  is_bus  is_truck  is_light  is_clear  is_child  severity
# 0       0       0         0         1         0         0         3
# 1       0       1         0         1         0         0         3
# 2       0       1         0         0         0         0         3
# 3       0       1         0         1         0         0         3
# 4       0       1         0         0         0         0         2

# %%
features = crashes.iloc[:,:-1].to_numpy()
severity = crashes.iloc[:,-1].to_numpy()

print('features: ', features.shape)
print('severity: ', severity.shape)
# Out:
# features:  (1169, 12)
# severity:  (1169,)

# %%
X_train, X_test, y_train, y_test = train_test_split(features, severity, train_size=0.8)

scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)

print('X_train.mean(): ', X_train.mean())
print('X_test.mean(): ', X_test.mean())

print('X_train.std(): ', X_train.std())
print('X_test.std(): ', X_test.std())
# Out:
# X_train.mean():  2.153159805333637e-17
# X_test.mean():  1.2652114240742525e-17
# X_train.std():  0.9999999999999982
# X_test.std():  0.9999999999999997

# %%
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
pred = knn.predict(X_test)

# %%
np.mean(pred == y_test)
# Out:
# 0.4658119658119658

# %%
def get_knn_pred(n):
    
    knn = KNeighborsClassifier(n_neighbors=n)
    knn.fit(X_train, y_train)
    
    return knn.predict(X_test)

def get_knn_acc(n):
    
    pred = get_knn_pred(n)
    
    return np.mean(pred == y_test)

# %%
get_knn_acc(3)
# Out:
# 0.4658119658119658

# %%
ks = np.arange(1,11)
accs = np.zeros(10)

for i, k_ in enumerate(ks):
    
    acc = get_knn_acc(k_)
    accs[i] = acc

# %%
pd.DataFrame(data = {'K':ks, 'accuracy':accs})
# Out:
#     K  accuracy
# 0   1  0.461538
# 1   2  0.414530
# 2   3  0.465812
# 3   4  0.504274
# 4   5  0.461538
# 5   6  0.435897
# 6   7  0.482906
# 7   8  0.461538
# 8   9  0.440171
# 9  10  0.461538

# %%
# Load data

crashes = pd.read_csv('data/crash_streets_vol.csv', parse_dates=['DATETIME'])

keep_cols = ['REPORT NUMBER',
            'DATETIME',
            'SPEEDLIMIT',
            'SURFACEWIDTH',
            'AWDT_ROUNDED',
            'one_way',
            'is_steep',
            'is_paved',
            'is_hwy',
            'is_bus',
            'is_truck',
            'is_light',
            'is_clear',
            'is_hit_run',
            'is_workzone',
            'is_child',
            'impaired',
            'speeding',
            'driver_16_25',
            'driver_65_plus',
            'severity',
            'geometry']

df = crashes[keep_cols]

# %%
df
# Out:
#         SPEEDLIMIT  SURFACEWIDTH  AWDT_ROUNDED      one_way     is_steep  \
# count  1169.000000   1169.000000   1169.000000  1169.000000  1169.000000
# mean     24.482464     43.625321  13743.627032     0.180496     0.174508
# std       2.561218     17.486342   8498.192547     0.384765     0.379708
# min       0.000000      0.000000   1000.000000     0.000000     0.000000
# 25%      25.000000     36.000000   8700.000000     0.000000     0.000000
# 50%      25.000000     43.000000  12100.000000     0.000000     0.000000
# 75%      25.000000     54.000000  17000.000000     0.000000     0.000000
# max      40.000000    120.000000  58700.000000     1.000000     1.000000
#
#           is_paved       is_hwy       is_bus     is_truck     is_light  \
# count  1169.000000  1169.000000  1169.000000  1169.000000  1169.000000
# mean      0.668948     0.003422     0.728828     0.050470     0.773311
# std       0.470793     0.058420     0.444755     0.219007     0.418869
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     1.000000
# 50%       1.000000     0.000000     1.000000     0.000000     1.000000
# 75%       1.000000     0.000000     1.000000     0.000000     1.000000
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#           is_clear   is_hit_run  is_workzone     is_child     impaired  \
# count  1169.000000  1169.000000  1169.000000  1169.000000  1169.000000
# mean      0.074423     0.157399     0.004277     0.023952     0.014542
# std       0.262570     0.364333     0.065288     0.152965     0.119763
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       0.000000     0.000000     0.000000     0.000000     0.000000
# 75%       0.000000     0.000000     0.000000     0.000000     0.000000
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#           speeding  driver_16_25  driver_65_plus     severity
# count  1169.000000   1169.000000     1169.000000  1169.000000
# mean      0.001711      0.111206        0.083832     2.508982
# std       0.041345      0.314522        0.277255     0.595471
# min       0.000000      0.000000        0.000000     1.000000
# 25%       0.000000      0.000000        0.000000     2.000000
# 50%       0.000000      0.000000        0.000000     3.000000
# 75%       0.000000      0.000000        0.000000     3.000000
# max       1.000000      1.000000        1.000000     4.000000

# %%
feats = df.iloc[:,2:-2].to_numpy()
severity = df['severity']

# %%
X_train, X_test, y_train, y_test = train_test_split(feats, severity, train_size=0.8, random_state=12345)

# %%
scale = StandardScaler().fit(X_train)
X_train = scale.transform(X_train)
X_test = scale.transform(X_test)

# %%
clf = LogisticRegression().fit(X_train, y_train)

# %%
clf.predict(X_test)
# Out:
# array([3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#        3, 3, 3, 3, 3, 3, 3, 2, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#        3, 3, 3, 3, 2, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#        3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#        3, 3, 3, 3, 3, 2, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#        3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 2, 3,
#        3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#        3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#        3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#        3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 2, 3, 3, 3, 3, 3,
#        3, 3, 3, 3, 3, 3, 3, 3, 2, 3, 3, 3, 3, 3], dtype=int64)

# %%
y_test
# Out:
# 1146    3
# 268     3
# 1145    1
# 973     3
# 162     3
#        ..
# 1001    3
# 732     2
# 437     2
# 208     3
# 422     2
# Name: severity, Length: 234, dtype: int64

# %% [markdown]
# From the study:
#
# `
